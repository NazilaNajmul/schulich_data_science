# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stream_flow = pd.read_csv("/Users/nazil/Downloads/Assignment1_StreamFlow_Subscription_Data.csv")

# %%
stream_flow.head()
# Out:
#    User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0        1   56   Other  Central  2020-06-07 01:53:37.656934
# 1        2   69   Other     West  2024-02-21 01:53:37.656980
# 2        3   46  Female    North  2022-10-06 01:53:37.656995
# 3        4   32  Female     East  2022-01-04 01:53:37.657006
# 4        5   60  Female    North  2020-03-13 01:53:37.657017
#
#   Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0           Premium            19.99    Credit Card              31.513153
# 1          Standard            14.99    Credit Card               4.982277
# 2          Standard            14.99         PayPal               4.114953
# 3          Standard            14.99    Credit Card              60.244820
# 4          Standard            14.99    Credit Card               4.711855
#
#   Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 0         Action           PC                1.195762        1023
# ...

# %%
stream_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  1000 non-null   int64
#  1   Age                      1000 non-null   int64
#  2   Gender                   1000 non-null   object
#  3   Location                 1000 non-null   object
#  4   Subscription_Start_Date  1000 non-null   object
#  5   Subscription_Type        1000 non-null   object
#  6   Monthly_Payment          1000 non-null   float64
#  7   Payment_Method           1000 non-null   object
#  8   Monthly_Hours_Watched    1000 non-null   float64
#  9   Favorite_Genre           1000 non-null   object
#  10  Devices_Used             1000 non-null   object
#  11  Average_Session_Length   1000 non-null   float64
#  12  Content_ID               1000 non-null   int64
#  13  Rating_Given             1000 non-null   int64
# ...

# %%
import datetime as dt

# %%
stream_flow.describe()
# Out:
#            User_ID          Age  Monthly_Payment  Monthly_Hours_Watched  \
# count  1000.000000  1000.000000      1000.000000            1000.000000
# mean    500.500000    44.385000        14.580000              19.071653
# std     288.819436    15.321669         3.404922              19.279140
# min       1.000000    18.000000         9.990000               0.041574
# 25%     250.750000    31.750000         9.990000               5.490739
# 50%     500.500000    45.000000        14.990000              13.361219
# 75%     750.250000    57.000000        14.990000              26.471636
# max    1000.000000    70.000000        19.990000             139.170408
#
#        Average_Session_Length   Content_ID  Rating_Given      Churned
# count             1000.000000  1000.000000   1000.000000  1000.000000
# mean                 1.893771  1049.201000      3.030000     0.246000
# std                  1.868852    29.268058      1.422365     0.430894
# ...

# %%
stream_flow["Gender"] = stream_flow["Gender"].astype("category")

# %%
stream_flow['Reason_for_Churn'] = stream_flow['Reason_for_Churn'].astype('str')

# %%
stream_flow['Subscription_Start_Date'] = pd.to_datetime(stream_flow['Subscription_Start_Date'])

# %%
stream_flow['Date_of_Churn'] = pd.to_datetime(stream_flow["Date_of_Churn"])

# %%
stream_flow['Location'] = stream_flow["Location"].astype('category')

# %%
stream_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  1000 non-null   int64
#  1   Age                      1000 non-null   int64
#  2   Gender                   1000 non-null   category
#  3   Location                 1000 non-null   category
#  4   Subscription_Start_Date  1000 non-null   datetime64[ns]
#  5   Subscription_Type        1000 non-null   object
#  6   Monthly_Payment          1000 non-null   float64
#  7   Payment_Method           1000 non-null   object
#  8   Monthly_Hours_Watched    1000 non-null   float64
#  9   Favorite_Genre           1000 non-null   object
#  10  Devices_Used             1000 non-null   object
#  11  Average_Session_Length   1000 non-null   float64
#  12  Content_ID               1000 non-null   int64
# ...

# %%
churned_df = stream_flow.loc[stream_flow['Churned'] == 1]

# %%
churned_df.describe()
# Out:
#           User_ID         Age        Subscription_Start_Date  Monthly_Payment  \
# count  246.000000  246.000000                            246       246.000000
# mean   505.361789   43.174797  2021-08-17 06:52:09.857642752        14.502195
# min     13.000000   18.000000     2019-05-13 01:53:37.658474         9.990000
# 25%    273.250000   30.000000  2020-04-22 07:53:37.663491072         9.990000
# 50%    501.500000   41.000000  2021-05-01 01:53:37.660559104        14.990000
# 75%    752.250000   56.000000  2022-11-26 19:53:37.664207360        14.990000
# max    999.000000   70.000000     2024-04-30 01:53:37.659297        19.990000
# std    284.676765   15.507139                            NaN         3.494289
#
#        Monthly_Hours_Watched  Average_Session_Length   Content_ID  \
# count             246.000000              246.000000   246.000000
# mean               17.039672                1.920114  1050.443089
# min                 0.041574                0.000821  1000.000000
# ...

# %%
churned_df.head()
# Out:
#     User_ID  Age Gender Location    Subscription_Start_Date Subscription_Type  \
# 12       13   41  Other    North 2021-04-22 01:53:37.657108          Standard
# 13       14   70  Other    South 2020-10-29 01:53:37.657119          Standard
# 14       15   53  Other     East 2023-10-06 01:53:37.657130          Standard
# 16       17   41  Other    South 2019-07-27 01:53:37.657151           Premium
# 29       30   39   Male    North 2019-11-05 01:53:37.657296          Standard
#
#     Monthly_Payment Payment_Method  Monthly_Hours_Watched Favorite_Genre  \
# 12            14.99   Direct Debit              14.011035         Sci-Fi
# 13            14.99   Direct Debit              35.339461         Sci-Fi
# 14            14.99    Credit Card              14.191293    Documentary
# 16            19.99    Credit Card              12.991876          Drama
# 29            14.99    Credit Card              22.258651         Comedy
#
# ...

# %%
churned_df.corr()['Churned']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 churned_df.corr()['Churned']
#
# File c:\Users\nazil\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\nazil\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
churned_df.loc[:, 'Gender'].tolist()
# Out:
# ['Other',
#  'Other',
#  'Other',
#  'Other',
#  'Male',
#  'Other',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Female',
#  'Female',
#  'Other',
#  'Male',
#  'Female',
#  'Female',
#  'Female',
#  'Female',
#  'Male',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Male',
#  'Other',
#  'Female',
#  'Female',
#  'Male',
#  'Male',
#  'Other',
#  'Male',
#  'Female',
#  'Other',
#  'Female',
#  'Male',
#  'Other',
#  'Male',
#  'Male',
#  'Female',
#  'Other',
#  'Other',
#  'Female',
#  'Other',
#  'Other',
#  'Female',
#  'Other',
#  'Other',
#  'Female',
#  'Male',
#  'Other',
#  'Male',
#  'Female',
#  'Other',
#  'Other',
#  'Male',
#  'Other',
#  'Female',
#  'Female',
#  'Female',
#  'Other',
#  'Other',
#  'Female',
#  'Male',
#  'Other',
#  'Female',
#  'Female',
#  'Male',
#  'Female',
#  'Female',
#  'Other',
#  'Other',
#  'Other',
#  'Male',
#  'Other',
#  'Male',
#  'Female',
#  'Female',
#  'Other',
#  'Male',
#  'Other',
#  'Other',
# ...

# %%
gender_count = churned_df.groupby('Gender').size()
# Out:
# C:\Users\nazil\AppData\Local\Temp\ipykernel_13600\1492986403.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gender_count = churned_df.groupby('Gender').size()

# %%
print(gender_count)
# Out:
# Gender
# Female    85
# Male      75
# Other     86
# dtype: int64

# %%
churned_df.loc[:, 'Devices_Used'].tolist()
# Out:
# ['Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Tablet',
#  'TV',
#  'Mobile',
#  'Tablet',
#  'Mobile',
#  'TV',
#  'Tablet',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'TV',
#  'TV',
#  'Mobile',
#  'TV',
#  'Mobile',
#  'Mobile',
#  'TV',
#  'Mobile',
#  'Tablet',
#  'Mobile',
#  'PC',
#  'TV',
#  'TV',
#  'Mobile',
#  'Tablet',
#  'Mobile',
#  'PC',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'TV',
#  'Mobile',
#  'Tablet',
#  'Tablet',
#  'TV',
#  'TV',
#  'PC',
#  'Mobile',
#  'TV',
#  'Mobile',
#  'TV',
#  'Tablet',
#  'TV',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'TV',
#  'Tablet',
#  'Mobile',
#  'TV',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Tablet',
#  'Tablet',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'Mobile',
#  'TV',
#  'TV',
#  'PC',
#  'Mobile',
#  'Mobile',
#  'Tablet',
#  'TV',
#  'PC',
#  'TV',
#  'Mobile',
#  'TV',
#  'Mobile',
# ...

# %%
devices_used_count = churned_df.groupby('Devices_Used').size()

# %%
print(devices_used_count)
# Out:
# Devices_Used
# Mobile    131
# PC         27
# TV         44
# Tablet     44
# dtype: int64

# %%
churned_df.loc[:, 'Reason_for_Churn'].tolist()
# Out:
# ['Found better service',
#  'Found better service',
#  'Price increase',
#  'Found better service',
#  'Price increase',
#  'Dissatisfied with content',
#  'Found better service',
#  'Found better service',
#  'Found better service',
#  'Dissatisfied with content',
#  'Price increase',
#  'Price increase',
#  'Personal reasons',
#  'Price increase',
#  'Personal reasons',
#  'Dissatisfied with content',
#  'Personal reasons',
#  'Dissatisfied with content',
#  'Price increase',
#  'Price increase',
#  'Dissatisfied with content',
#  'Dissatisfied with content',
#  'Personal reasons',
#  'Found better service',
#  'Personal reasons',
#  'Found better service',
#  'Personal reasons',
#  'Price increase',
#  'Dissatisfied with content',
#  'Found better service',
#  'Price increase',
#  'Personal reasons',
#  'Price increase',
#  'Found better service',
#  'Found better service',
#  'Found better service',
#  'Price increase',
#  'Dissatisfied with content',
#  'Found better service',
# ...

# %%
reasons_count = churned_df.groupby('Reason_for_Churn').size()

# %%
print(reasons_count)
# Out:
# Reason_for_Churn
# Dissatisfied with content    52
# Found better service         64
# Personal reasons             62
# Price increase               68
# dtype: int64

# %%
age_count = churned_df.groupby('Age').size()

# %%
print(age_count)
# Out:
# Age
# 18    7
# 19    6
# 20    4
# 21    5
# 22    4
# 23    4
# 24    3
# 25    4
# 26    6
# 27    6
# 28    4
# 29    8
# 30    3
# 31    2
# 32    2
# 33    5
# 34    6
# 35    5
# 36    8
# 37    8
# 38    6
# 39    8
# 40    2
# 41    8
# 42    5
# 43    7
# 44    5
# 45    3
# 46    2
# 47    3
# 48    4
# 49    3
# 50    3
# 51    5
# 52    6
# 53    7
# 54    1
# 55    4
# 56    4
# 57    2
# 58    3
# 59    5
# 61    6
# 62    3
# 63    3
# 64    4
# 65    8
# 66    5
# 67    4
# 68    8
# 69    6
# 70    3
# dtype: int64

# %%
location_count = churned_df.groupby('Location').size()
print(location_count)
# Out:
# Location
# Central    47
# East       60
# North      53
# South      42
# West       44
# dtype: int64

# %%
non_churned_df = stream_flow.loc[stream_flow['Churned'] == 0]

# %%
non_churned_df.describe()
# Out:
#            User_ID         Age        Subscription_Start_Date  \
# count   754.000000  754.000000                            754
# mean    498.913793   44.779841  2021-09-29 07:03:01.057674496
# min       1.000000   18.000000     2019-05-10 01:53:37.659073
# 25%     245.250000   32.000000  2020-05-30 01:53:37.659966464
# 50%     500.000000   45.500000  2021-09-25 13:53:37.661242112
# 75%     748.500000   57.000000  2023-01-16 13:53:37.662548480
# max    1000.000000   70.000000     2024-05-06 01:53:37.662112
# std     290.327761   15.250257                            NaN
#
#        Monthly_Payment  Monthly_Hours_Watched  Average_Session_Length  \
# count       754.000000             754.000000              754.000000
# mean         14.605385              19.734607                1.885177
# min           9.990000               0.076891                0.000486
# 25%           9.990000               5.657050                0.516868
# ...

# %%
payment = non_churned_df.groupby('Monthly_Payment').size()

# %%
print(payment)
# Out:
# Monthly_Payment
# 9.99     203
# 14.99    406
# 19.99    145
# dtype: int64

# %%
churned_payment = churned_df.groupby('Monthly_Payment').size()

# %%
print(churned_payment)
# Out:
# Monthly_Payment
# 9.99      73
# 14.99    124
# 19.99     49
# dtype: int64

# %%
non_churned_devices = non_churned_df.groupby('Devices_Used').size()
print(non_churned_devices)
# Out:
# Devices_Used
# Mobile    277
# PC        147
# TV        157
# Tablet    173
# dtype: int64

# %%
sns.heatmap(churned_df.iloc[:, "Devices_Used":].corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 sns.heatmap(churned_df.iloc[:, "Devices_Used":].corr(), annot=True)
#
# File c:\Users\nazil\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\nazil\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1694, in _iLocIndexer._getitem_tuple(self, tup)
#    1691 with suppress(IndexingError):
#    1692     return self._getitem_lowerdim(tup)
# -> 1694 return self._getitem_tuple_same_dim(tup)
#
# ...
