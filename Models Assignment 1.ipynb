# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %%
def read_data(farms_csv, processing_csv, centers_csv):
    """Reads CSVs and returns data dictionaries, handling string IDs"""
    farms_df = pd.read_csv(farms_csv)
    farms_df["Farm_ID"] = farms_df["Farm_ID"].str.replace("Farm_", "").astype(int)
    
    plant_df = pd.read_csv(processing_csv)
    plant_df["Processing_Plant_ID"] = plant_df["Processing_Plant_ID"].str.replace("Plant_", "").astype(int)

    centers_df = pd.read_csv(centers_csv)
    centers_df["Center_ID"] = centers_df["Center_ID"].str.replace("Center_", "").astype(int)

    farm_ids = farms_df["Farm_ID"].unique().tolist()
    farm_ids.sort()
    plant_ids = plant_df["Processing_Plant_ID"].unique().tolist()
    plant_ids.sort()
    center_ids = centers_df["Center_ID"].unique().tolist()
    center_ids.sort()

    farm_capacity = dict(zip(farms_df["Farm_ID"], farms_df["Bio_Material_Capacity_Tons"]))
    farm_raw_cost = dict(zip(farms_df["Farm_ID"], farms_df["Cost_Per_Ton"]))

    trans_f2p_cols = [c for c in farms_df.columns if c.startswith("Transport_Cost_To_Plant_")]
    farm_to_plant_cost = {}
    for _, row in farms_df.iterrows():
        f_id = row["Farm_ID"]
        for col in trans_f2p_cols:
            p_id_str = col.split("Transport_Cost_To_Plant_")[1]
            p_id = int(p_id_str)
            cost_val = row[col]
            farm_to_plant_cost[(f_id, p_id)] = cost_val

    plant_region = dict(zip(plant_df["Processing_Plant_ID"], plant_df["Region"]))
    plant_capacity = dict(zip(plant_df["Processing_Plant_ID"], plant_df["Capacity_Tons"]))
    plant_proc_cost = dict(zip(plant_df["Processing_Plant_ID"], plant_df["Processing_Cost_Per_Ton"]))

    trans_p2c_cols = [c for c in plant_df.columns if c.startswith("Transport_Cost_To_Center_")]
    plant_to_center_cost = {}
    for _, row in plant_df.iterrows():
        p_id = row["Processing_Plant_ID"]
        for col in trans_p2c_cols:
            c_id_str = col.split("Transport_Cost_To_Center_")[1]
            c_id = int(c_id_str)
            cost_val = row[col]
            plant_to_center_cost[(p_id, c_id)] = cost_val

    center_demand = dict(zip(centers_df["Center_ID"], centers_df["Requested_Demand_Tons"]))
    center_region = dict(zip(centers_df["Center_ID"], centers_df["Region"]))

    return farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, center_region, plant_region

# %%
def solve_bioagri(farms_csv, processing_csv, centers_csv):
    """Base model with 3 stage supply chain"""
    farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, _, _ = read_data(farms_csv, processing_csv, centers_csv)

    model = gp.Model("BioAgri_FixedIDs")
    x = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            x[(f_id, p_id)] = model.addVar(lb=0.0, name=f"x_{f_id}_{p_id}")
    y = {}
    for p_id in plant_ids:
        for c_id in center_ids:
            y[(p_id, c_id)] = model.addVar(lb=0.0, name=f"y_{p_id}_{c_id}")

    farm_transport_expr = gp.quicksum(
        (farm_raw_cost[f_id] + farm_to_plant_cost[(f_id, p_id)]) * x[(f_id, p_id)]
        for f_id in farm_ids
        for p_id in plant_ids
    )
    proc_expr = gp.quicksum(
        plant_proc_cost[p_id] * gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        for p_id in plant_ids
    )
    dist_expr = gp.quicksum(
        plant_to_center_cost[(p_id, c_id)] * y[(p_id, c_id)]
        for p_id in plant_ids
        for c_id in center_ids
    )
    model.setObjective(farm_transport_expr + proc_expr + dist_expr, GRB.MINIMIZE)

    for f_id in farm_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for p_id in plant_ids) <= farm_capacity[f_id],
            name=f"Max_Farm_Capacity_Farm_{f_id}"
        )

    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= plant_capacity[p_id],
            name=f"Max_Plant_Capacity_Plant_{p_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for c_id in center_ids) ==
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids),
            name=f"Flow_Conservation_Plant_{p_id}"
        )
    for c_id in center_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for p_id in plant_ids) == center_demand[c_id],
            name=f"CenterDem_{c_id}"
        )
    model.optimize()
    if model.status == GRB.OPTIMAL:
        print(f"\nOptimal solution found. Minimum Cost = {model.objVal:,.2f}\n")
        farm_plant_data = []
        for (f_id, p_id) in x:
          if x[(f_id, p_id)].X > 1e-6:
             farm_plant_data.append({"Farm": f_id, "Plant": p_id, "Flow (tons)": x[(f_id, p_id)].X})
        
        farm_plant_df = pd.DataFrame(farm_plant_data)
        print("\\nFarm->Plant Flows:\\n", farm_plant_df)

        plant_center_data = []
        for (p_id, c_id) in y:
            if y[(p_id, c_id)].X > 1e-6:
              plant_center_data.append({"Plant": p_id, "Center": c_id, "Flow (tons)": y[(p_id, c_id)].X})

        plant_center_df = pd.DataFrame(plant_center_data)
        print("\\nPlant->Center Flows:\\n", plant_center_df)
    else:
        print(f"Model ended with status {model.status}")

    print("Objective of Base Model: \n", model.getObjective())
    print("\\nConstraints of Base Model:\\n", model.getConstrs())

    return model

# %%
def solve_bioagri_same_region(farms_csv, processing_csv, centers_csv):
    """Same as base but only allows transport between plants and centers of same region."""
    farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, center_region, plant_region = read_data(farms_csv, processing_csv, centers_csv)

    model = gp.Model("BioAgri_SameRegion")
    x = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            x[(f_id, p_id)] = model.addVar(lb=0.0, name=f"x_{f_id}_{p_id}")
    y = {}
    for p_id in plant_ids:
        for c_id in center_ids:
            if (p_id, c_id) in plant_to_center_cost:
                y[(p_id, c_id)] = model.addVar(lb=0.0, name=f"y_{p_id}_{c_id}")
                print(f"Variable Created {p_id} to {c_id}")

    farm_transport_expr = gp.quicksum(
        (farm_raw_cost[f_id] + farm_to_plant_cost[(f_id, p_id)]) * x[(f_id, p_id)]
        for f_id in farm_ids
        for p_id in plant_ids
    )
    proc_expr = gp.quicksum(
        plant_proc_cost[p_id] * gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        for p_id in plant_ids
    )
    dist_expr = gp.quicksum(
        plant_to_center_cost[(p_id, c_id)] * y[(p_id, c_id)]
        for (p_id, c_id) in plant_to_center_cost
    )
    model.setObjective(farm_transport_expr + proc_expr + dist_expr, GRB.MINIMIZE)

    for f_id in farm_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for p_id in plant_ids) <= farm_capacity[f_id],
            name=f"Max_Farm_Capacity_Farm_{f_id}"
        )

    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= plant_capacity[p_id],
            name=f"Max_Plant_Capacity_Plant_{p_id}"
        )
    for p_id in plant_ids:
        in_flow = gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        out_flow = gp.quicksum(y[(p_id, c_id)] for c_id in center_ids if (p_id, c_id) in y)
        model.addConstr(out_flow == in_flow, name=f"Flow_Conservation_Plant_{p_id}")
    for c_id in center_ids:
        inbound = gp.quicksum(y[(p_id, c_id)] for p_id in plant_ids if (p_id, c_id) in y)
        model.addConstr(inbound == center_demand[c_id], name=f"CenterDem_{c_id}")
        
    model.optimize()
    if model.status == GRB.OPTIMAL:
        print(f"\nOptimal solution found (same-region only). Minimum Cost = {model.objVal:,.2f}\n")
        
        farm_plant_data = []
        for (f_id, p_id) in x:
          if x[(f_id, p_id)].X > 1e-6:
             farm_plant_data.append({"Farm": f_id, "Plant": p_id, "Flow (tons)": x[(f_id, p_id)].X, "Plant Region": plant_region[p_id]})
        
        farm_plant_df = pd.DataFrame(farm_plant_data)
        print("\\nFarm->Plant Flows:\\n", farm_plant_df)

        plant_center_data = []
        for (p_id, c_id) in y:
            if y[(p_id, c_id)].X > 1e-6:
              plant_center_data.append({"Plant": p_id, "Center": c_id, "Flow (tons)": y[(p_id, c_id)].X, "Center Region": center_region[c_id]})
        plant_center_df = pd.DataFrame(plant_center_data)
        print("\\nPlant->Center Flows:\\n", plant_center_df)
    else:
        print(f"Model ended with status {model.status}")

    print("Objective of Same Region Model: \n", model.getObjective())
    print("\\nConstraints of Same Region Model:\\n", model.getConstrs())
    
    return model

# %%
def solve_bioagri_high_quality(farms_csv, processing_csv, centers_csv):
    """Only allows raw material from farms with a quality of level 3 or 4"""
    farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, _, _ = read_data(farms_csv, processing_csv, centers_csv)

    farms_df = pd.read_csv(farms_csv)
    farms_df["Farm_ID"] = farms_df["Farm_ID"].str.replace("Farm_", "").astype(int)
    farms_df = farms_df[ farms_df["Quality"] >= 3 ].copy()
    farm_ids = farms_df["Farm_ID"].unique().tolist()
    farm_ids.sort()
    farm_capacity = dict(zip(farms_df["Farm_ID"], farms_df["Bio_Material_Capacity_Tons"]))
    farm_raw_cost = dict(zip(farms_df["Farm_ID"], farms_df["Cost_Per_Ton"]))

    trans_f2p_cols = [c for c in farms_df.columns if c.startswith("Transport_Cost_To_Plant_")]
    farm_to_plant_cost = {}
    for _, row in farms_df.iterrows():
        f_id = row["Farm_ID"]
        for col in trans_f2p_cols:
            p_id_str = col.split("Transport_Cost_To_Plant_")[1]
            p_id = int(p_id_str)
            cost_val = row[col]
            farm_to_plant_cost[(f_id, p_id)] = cost_val
    
    model = gp.Model("BioAgri_HighQualityOnly")
    x = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            x[(f_id, p_id)] = model.addVar(lb=0.0, name=f"x_{f_id}_{p_id}")
    y = {}
    for p_id in plant_ids:
        for c_id in center_ids:
            y[(p_id, c_id)] = model.addVar(lb=0.0, name=f"y_{p_id}_{c_id}")

    farm_transport_expr = gp.quicksum(
        (farm_raw_cost[f_id] + farm_to_plant_cost[(f_id, p_id)]) * x[(f_id, p_id)]
        for f_id in farm_ids
        for p_id in plant_ids
    )
    proc_expr = gp.quicksum(
        plant_proc_cost[p_id] * gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        for p_id in plant_ids
    )
    dist_expr = gp.quicksum(
        plant_to_center_cost[(p_id, c_id)] * y[(p_id, c_id)]
        for p_id in plant_ids
        for c_id in center_ids
    )
    model.setObjective(farm_transport_expr + proc_expr + dist_expr, GRB.MINIMIZE)
    for f_id in farm_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for p_id in plant_ids) <= farm_capacity[f_id],
            name=f"Max_Farm_Capacity_Farm_{f_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= plant_capacity[p_id],
            name=f"Max_Plant_Capacity_Plant_{p_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for c_id in center_ids) ==
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids),
            name=f"PlantFlow_{p_id}"
        )
    for c_id in center_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for p_id in plant_ids) == center_demand[c_id],
            name=f"CenterDem_{c_id}"
        )
        
    model.optimize()
    if model.status == GRB.OPTIMAL:
        print(f"\nOptimal solution found (Quality >= 3 only). Minimum Cost = {model.objVal:,.2f}\n")
        
        farm_plant_data = []
        for (f_id, p_id) in x:
          if x[(f_id, p_id)].X > 1e-6:
            farm_plant_data.append({"Farm": f_id, "Plant": p_id, "Flow (tons)": x[(f_id, p_id)].X})
        
        farm_plant_df = pd.DataFrame(farm_plant_data)
        print("\\nFarm->Plant Flows:\\n", farm_plant_df)

        plant_center_data = []
        for (p_id, c_id) in y:
            if y[(p_id, c_id)].X > 1e-6:
              plant_center_data.append({"Plant": p_id, "Center": c_id, "Flow (tons)": y[(p_id, c_id)].X})

        plant_center_df = pd.DataFrame(plant_center_data)
        print("\\nPlant->Center Flows:\\n", plant_center_df)
    else:
        print(f"Model ended with status {model.status}")

    return model

# %%
def solve_bioagri_3pct_limit(farms_csv, processing_csv, centers_csv):
    """
    Builds and solves a multi-stage supply chain model using Gurobi, 
    adding a constraint that each facility can process no more than 3% 
    of the total raw material.
    """
    
    farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, _, _ = read_data(farms_csv, processing_csv, centers_csv)


    model = gp.Model("BioAgri_3pctLimit")

    x = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            x[(f_id, p_id)] = model.addVar(lb=0.0, name=f"x_{f_id}_{p_id}")
    y = {}
    for p_id in plant_ids:
        for c_id in center_ids:
            y[(p_id, c_id)] = model.addVar(lb=0.0, name=f"y_{p_id}_{c_id}")

    farm_transport_expr = gp.quicksum(
        (farm_raw_cost[f_id] + farm_to_plant_cost[(f_id, p_id)]) * x[(f_id, p_id)]
        for f_id in farm_ids
        for p_id in plant_ids
    )
    proc_expr = gp.quicksum(
        plant_proc_cost[p_id] * gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        for p_id in plant_ids
    )
    dist_expr = gp.quicksum(
        plant_to_center_cost[(p_id, c_id)] * y[(p_id, c_id)]
        for p_id in plant_ids
        for c_id in center_ids
    )
    model.setObjective(farm_transport_expr + proc_expr + dist_expr, GRB.MINIMIZE)
    
    total_demand = sum(center_demand.values())

    alloc = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            alloc[(f_id, p_id)] = model.addVar(lb=0, ub = 1, name=f"allocation_{f_id}_{p_id}")
    
    for f_id in farm_ids:
           model.addConstr(gp.quicksum(alloc[(f_id,p_id)] for p_id in plant_ids) == 1, name=f"Sum_Allocation_Percentages_{f_id}")
   
    for f_id in farm_ids:
           for p_id in plant_ids:
              model.addConstr(x[(f_id,p_id)] <= alloc[(f_id,p_id)]*farm_capacity[f_id], name=f"Farm_Plant_Capacity_Allocation_{f_id}_{p_id}")
    
    for f_id in farm_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for p_id in plant_ids) <= farm_capacity[f_id],
            name=f"Max_Farm_Capacity_Farm_{f_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= plant_capacity[p_id],
            name=f"Max_Plant_Capacity_Plant_{p_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for c_id in center_ids) ==
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids),
            name=f"PlantFlow_{p_id}"
        )
    for c_id in center_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for p_id in plant_ids) == center_demand[c_id],
            name=f"CenterDem_{c_id}"
        )
    
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= 0.03 * total_demand,
            name=f"Max3pctPlant_{p_id}"
        )
        
    model.optimize()
    
    if model.status == GRB.OPTIMAL:
      print(f"\nOptimal solution found (3% limit). Minimum Cost = {model.objVal:,.2f}\n")
      for (f_id, p_id) in x:
            if x[(f_id, p_id)].X > 1e-6:
              print(f"From Farm {f_id} -> Plant {p_id}: {x[(f_id, p_id)].X:,.2f} tons")
      for (p_id, c_id) in y:
            if y[(p_id, c_id)].X > 1e-6:
                print(f"From Plant {p_id} -> Center {c_id}: {y[(p_id, c_id)].X:,.2f} tons")
    else:
      print(f"Model ended with status {model.status}")

    return model

# %%
def solve_bioagri_50pct_limit_per_center(farms_csv, processing_csv, centers_csv, center_limit=0.5):
    """
    Builds and solves a multi-stage supply chain model using Gurobi, adding a constraint that
    no single plant can supply more than 50% of a given center's demand (risk mitigation).
    """
    farm_ids, plant_ids, center_ids, farm_capacity, farm_raw_cost, farm_to_plant_cost, plant_capacity, plant_proc_cost, plant_to_center_cost, center_demand, _, _ = read_data(farms_csv, processing_csv, centers_csv)

    model = gp.Model("BioAgri_50pctCenter")
    x = {}
    for f_id in farm_ids:
        for p_id in plant_ids:
            x[(f_id, p_id)] = model.addVar(lb=0.0, name=f"x_{f_id}_{p_id}")
    y = {}
    for p_id in plant_ids:
        for c_id in center_ids:
            y[(p_id, c_id)] = model.addVar(lb=0.0, name=f"y_{p_id}_{c_id}")
    
    farm_transport_expr = gp.quicksum(
        (farm_raw_cost[f_id] + farm_to_plant_cost[(f_id, p_id)]) * x[(f_id, p_id)]
        for f_id in farm_ids
        for p_id in plant_ids
    )
    proc_expr = gp.quicksum(
        plant_proc_cost[p_id] * gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids)
        for p_id in plant_ids
    )
    dist_expr = gp.quicksum(
        plant_to_center_cost[(p_id, c_id)] * y[(p_id, c_id)]
        for p_id in plant_ids
        for c_id in center_ids
    )

    model.setObjective(farm_transport_expr + proc_expr + dist_expr, GRB.MINIMIZE)
   
    for f_id in farm_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for p_id in plant_ids) <= farm_capacity[f_id],
            name=f"Max_Farm_Capacity_Farm_{f_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids) <= plant_capacity[p_id],
            name=f"Max_Plant_Capacity_Plant_{p_id}"
        )
    for p_id in plant_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for c_id in center_ids) ==
            gp.quicksum(x[(f_id, p_id)] for f_id in farm_ids),
            name=f"Flow_Conservation_Plant_{p_id}"
        )
    for c_id in center_ids:
        model.addConstr(
            gp.quicksum(y[(p_id, c_id)] for p_id in plant_ids) == center_demand[c_id],
            name=f"Center_Demand_Center_{c_id}"
        )
    
    for c_id in center_ids:
        demand_c = center_demand[c_id]
        for p_id in plant_ids:
            model.addConstr(
                y[(p_id, c_id)] <=  center_limit * demand_c,
                name=f"Max_50pct_Plant_{p_id}_To_Center_{c_id}"
            )
    model.optimize()
    
    if model.status == GRB.OPTIMAL:
        print(f"\nOptimal solution found (50% center limit). Minimum Cost = {model.objVal:,.2f}\n")
        
        farm_plant_data = []
        for (f_id, p_id) in x:
          if x[(f_id, p_id)].X > 1e-6:
            farm_plant_data.append({"Farm": f_id, "Plant": p_id, "Flow (tons)": x[(f_id, p_id)].X})
        
        farm_plant_df = pd.DataFrame(farm_plant_data)
        print("\\nFarm->Plant Flows:\\n", farm_plant_df)
        
        plant_center_data = []
        for (p_id, c_id) in y:
            if y[(p_id, c_id)].X > 1e-6:
              plant_center_data.append({"Plant": p_id, "Center": c_id, "Flow (tons)": y[(p_id, c_id)].X})

        plant_center_df = pd.DataFrame(plant_center_data)
        print("\\nPlant->Center Flows:\\n", plant_center_df)
    else:
        print(f"Model ended with status {model.status}")

    return model

# %%
if __name__ == "__main__":
    
    farms_csv = "c:/MBAN- Schulich/MBAN- Sem 3/Models & Applications in Op Research/Assignment 1/farms.csv"
    processing_csv = "c:/MBAN- Schulich/MBAN- Sem 3/Models & Applications in Op Research/Assignment 1/processing.csv"
    centers_csv = "c:/MBAN- Schulich/MBAN- Sem 3/Models & Applications in Op Research/Assignment 1/centers.csv"

    # (b) Solve base Model
    print("Base Model:\n")
    model_b = solve_bioagri(farms_csv, processing_csv, centers_csv)
    
    # (c) Solve same-region model
    print("\nSame Region Model:\n")
    model_c = solve_bioagri_same_region(farms_csv, processing_csv, centers_csv)

    # (d) Solve high-quality model
    print("\nHigh Quality Model:\n")
    model_d = solve_bioagri_high_quality(farms_csv, processing_csv, centers_csv)
    
     # (e) solve plant constraint
    print("\n3% plant constraint Model:\n")
    model_e_1 = solve_bioagri_3pct_limit(farms_csv, processing_csv, centers_csv)

    # (e) solve 50% center constraint
    print("\n50% Center Limit Model:\n")
    model_e_2 = solve_bioagri_50pct_limit_per_center(farms_csv, processing_csv, centers_csv, center_limit=0.5)
# Out:
# Base Model:
#
# Set parameter Username
# Set parameter LicenseID to value 2610005
# Academic license - for non-commercial use only - expires 2026-01-14
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 387 rows, 6318 columns and 17118 nonzeros
# Model fingerprint: 0x14917975
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve time: 0.01s
# Presolved: 387 rows, 6318 columns, 17118 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1171568e+04   2.902000e+04   0.000000e+00      0s
#      370    2.2970900e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 370 iterations and 0.04 seconds (0.02 work units)
# Optimal objective  2.297089973e+06
#
# Optimal solution found. Minimum Cost = 2,297,089.97
#
# \nFarm->Plant Flows:\n     Farm  Plant  Flow (tons)
# 0      4      9        367.0
# 1      5      6        499.0
# 2      6     16        417.0
# 3     14      6        526.0
# 4     15      9        441.0
# ..   ...    ...          ...
# 69   226      2        386.0
# 70   238      6        269.0
# 71   240     10        317.0
# 72   243      1        413.0
# 73   244      2        255.0
#
# [74 rows x 3 columns]
# \nPlant->Center Flows:\n      Plant  Center  Flow (tons)
# 0        1       7        480.0
# 1        1       8        149.0
# 2        1      10        469.0
# 3        1      15        320.0
# 4        1      18        437.0
# ..     ...     ...          ...
# 98      16      82         92.0
# 99      16      93        464.0
# 100     16      95         87.0
# 101     16      97        250.0
# 102     16     102        358.0
#
# [103 rows x 3 columns]
# Objective of Base Model:
#  133.78969834448876 x_1_1 + 133.93749812154073 x_1_2 + 135.69467087802533 x_1_3 + 136.76787821004586 x_1_4 + 136.35132533030549 x_1_5 + 134.98549498561474 x_1_6 + 136.32063631346475 x_1_7 + 137.47798539719855 x_1_8 + 132.76333201373856 x_1_9 + 134.65079751410138 x_1_10 + 136.4701860921011 x_1_11 + 137.255323604862 x_1_12 + 135.50148023571614 x_1_13 + 137.25179196198457 x_1_14 + 137.011883203874 x_1_15 + 135.31903754628047 x_1_16 + 136.80501224698398 x_1_17 + 
#
# Same Region Model:
#
# Variable Created 1 to 1
# Variable Created 1 to 2
# Variable Created 1 to 3
# Variable Created 1 to 4
# Variable Created 1 to 5
# Variable Created 1 to 6
# Variable Created 1 to 7
# Variable Created 1 to 8
# Variable Created 1 to 9
# Variable Created 1 to 10
# Variable Created 1 to 11
# Variable Created 1 to 12
# Variable Created 1 to 13
# Variable Created 1 to 14
# Variable Created 1 to 15
# Variable Created 1 to 16
# Variable Created 1 to 17
# Variable Created 1 to 18
# Variable Created 1 to 19
# Variable Created 1 to 20
# Variable Created 1 to 21
# Variable Created 1 to 22
# Variable Created 1 to 23
# Variable Created 1 to 24
# Variable Created 1 to 25
# Variable Created 1 to 26
# Variable Created 1 to 27
# Variable Created 1 to 28
# Variable Created 1 to 29
# Variable Created 1 to 30
# Variable Created 1 to 31
# Variable Created 1 to 32
# Variable Created 1 to 33
# Variable Created 1 to 34
# Variable Created 1 to 35
# Variable Created 1 to 36
# Variable Created 1 to 37
# Variable Created 1 to 38
# Variable Created 1 to 39
# Variable Created 1 to 40
# Variable Created 1 to 41
# Variable Created 1 to 42
# Variable Created 1 to 43
# Variable Created 1 to 44
# Variable Created 1 to 45
# Variable Created 1 to 46
# Variable Created 1 to 47
# Variable Created 1 to 48
# Variable Created 1 to 49
# Variable Created 1 to 50
# Variable Created 1 to 51
# Variable Created 1 to 52
# Variable Created 1 to 53
# Variable Created 1 to 54
# Variable Created 1 to 55
# Variable Created 1 to 56
# Variable Created 1 to 57
# Variable Created 1 to 58
# Variable Created 1 to 59
# Variable Created 1 to 60
# Variable Created 1 to 61
# Variable Created 1 to 62
# Variable Created 1 to 63
# Variable Created 1 to 64
# Variable Created 1 to 65
# Variable Created 1 to 66
# Variable Created 1 to 67
# Variable Created 1 to 68
# Variable Created 1 to 69
# Variable Created 1 to 70
# Variable Created 1 to 71
# Variable Created 1 to 72
# Variable Created 1 to 73
# Variable Created 1 to 74
# Variable Created 1 to 75
# Variable Created 1 to 76
# Variable Created 1 to 77
# Variable Created 1 to 78
# Variable Created 1 to 79
# Variable Created 1 to 80
# Variable Created 1 to 81
# Variable Created 1 to 82
# Variable Created 1 to 83
# Variable Created 1 to 84
# Variable Created 1 to 85
# Variable Created 1 to 86
# Variable Created 1 to 87
# Variable Created 1 to 88
# Variable Created 1 to 89
# Variable Created 1 to 90
# Variable Created 1 to 91
# Variable Created 1 to 92
# Variable Created 1 to 93
# Variable Created 1 to 94
# Variable Created 1 to 95
# Variable Created 1 to 96
# Variable Created 1 to 97
# Variable Created 1 to 98
# Variable Created 1 to 99
# Variable Created 1 to 100
# Variable Created 1 to 101
# Variable Created 1 to 102
# Variable Created 2 to 1
# Variable Created 2 to 2
# Variable Created 2 to 3
# Variable Created 2 to 4
# Variable Created 2 to 5
# Variable Created 2 to 6
# Variable Created 2 to 7
# Variable Created 2 to 8
# Variable Created 2 to 9
# Variable Created 2 to 10
# Variable Created 2 to 11
# Variable Created 2 to 12
# Variable Created 2 to 13
# Variable Created 2 to 14
# Variable Created 2 to 15
# Variable Created 2 to 16
# Variable Created 2 to 17
# Variable Created 2 to 18
# Variable Created 2 to 19
# Variable Created 2 to 20
# Variable Created 2 to 21
# Variable Created 2 to 22
# Variable Created 2 to 23
# Variable Created 2 to 24
# Variable Created 2 to 25
# Variable Created 2 to 26
# Variable Created 2 to 27
# Variable Created 2 to 28
# Variable Created 2 to 29
# Variable Created 2 to 30
# Variable Created 2 to 31
# Variable Created 2 to 32
# Variable Created 2 to 33
# Variable Created 2 to 34
# Variable Created 2 to 35
# Variable Created 2 to 36
# Variable Created 2 to 37
# Variable Created 2 to 38
# Variable Created 2 to 39
# Variable Created 2 to 40
# Variable Created 2 to 41
# Variable Created 2 to 42
# Variable Created 2 to 43
# Variable Created 2 to 44
# Variable Created 2 to 45
# Variable Created 2 to 46
# Variable Created 2 to 47
# Variable Created 2 to 48
# Variable Created 2 to 49
# Variable Created 2 to 50
# Variable Created 2 to 51
# Variable Created 2 to 52
# Variable Created 2 to 53
# Variable Created 2 to 54
# Variable Created 2 to 55
# Variable Created 2 to 56
# Variable Created 2 to 57
# Variable Created 2 to 58
# Variable Created 2 to 59
# Variable Created 2 to 60
# Variable Created 2 to 61
# Variable Created 2 to 62
# Variable Created 2 to 63
# Variable Created 2 to 64
# Variable Created 2 to 65
# Variable Created 2 to 66
# Variable Created 2 to 67
# Variable Created 2 to 68
# Variable Created 2 to 69
# Variable Created 2 to 70
# Variable Created 2 to 71
# Variable Created 2 to 72
# Variable Created 2 to 73
# Variable Created 2 to 74
# Variable Created 2 to 75
# Variable Created 2 to 76
# Variable Created 2 to 77
# Variable Created 2 to 78
# Variable Created 2 to 79
# Variable Created 2 to 80
# Variable Created 2 to 81
# Variable Created 2 to 82
# Variable Created 2 to 83
# Variable Created 2 to 84
# Variable Created 2 to 85
# Variable Created 2 to 86
# Variable Created 2 to 87
# Variable Created 2 to 88
# Variable Created 2 to 89
# Variable Created 2 to 90
# Variable Created 2 to 91
# Variable Created 2 to 92
# Variable Created 2 to 93
# Variable Created 2 to 94
# Variable Created 2 to 95
# Variable Created 2 to 96
# Variable Created 2 to 97
# Variable Created 2 to 98
# Variable Created 2 to 99
# Variable Created 2 to 100
# Variable Created 2 to 101
# Variable Created 2 to 102
# Variable Created 3 to 1
# Variable Created 3 to 2
# Variable Created 3 to 3
# Variable Created 3 to 4
# Variable Created 3 to 5
# Variable Created 3 to 6
# Variable Created 3 to 7
# Variable Created 3 to 8
# Variable Created 3 to 9
# Variable Created 3 to 10
# Variable Created 3 to 11
# Variable Created 3 to 12
# Variable Created 3 to 13
# Variable Created 3 to 14
# Variable Created 3 to 15
# Variable Created 3 to 16
# Variable Created 3 to 17
# Variable Created 3 to 18
# Variable Created 3 to 19
# Variable Created 3 to 20
# Variable Created 3 to 21
# Variable Created 3 to 22
# Variable Created 3 to 23
# Variable Created 3 to 24
# Variable Created 3 to 25
# Variable Created 3 to 26
# Variable Created 3 to 27
# Variable Created 3 to 28
# Variable Created 3 to 29
# Variable Created 3 to 30
# Variable Created 3 to 31
# Variable Created 3 to 32
# Variable Created 3 to 33
# Variable Created 3 to 34
# Variable Created 3 to 35
# Variable Created 3 to 36
# Variable Created 3 to 37
# Variable Created 3 to 38
# Variable Created 3 to 39
# Variable Created 3 to 40
# Variable Created 3 to 41
# Variable Created 3 to 42
# Variable Created 3 to 43
# Variable Created 3 to 44
# Variable Created 3 to 45
# Variable Created 3 to 46
# Variable Created 3 to 47
# Variable Created 3 to 48
# Variable Created 3 to 49
# Variable Created 3 to 50
# Variable Created 3 to 51
# Variable Created 3 to 52
# Variable Created 3 to 53
# Variable Created 3 to 54
# Variable Created 3 to 55
# Variable Created 3 to 56
# Variable Created 3 to 57
# Variable Created 3 to 58
# Variable Created 3 to 59
# Variable Created 3 to 60
# Variable Created 3 to 61
# Variable Created 3 to 62
# Variable Created 3 to 63
# Variable Created 3 to 64
# Variable Created 3 to 65
# Variable Created 3 to 66
# Variable Created 3 to 67
# Variable Created 3 to 68
# Variable Created 3 to 69
# Variable Created 3 to 70
# Variable Created 3 to 71
# Variable Created 3 to 72
# Variable Created 3 to 73
# Variable Created 3 to 74
# Variable Created 3 to 75
# Variable Created 3 to 76
# Variable Created 3 to 77
# Variable Created 3 to 78
# Variable Created 3 to 79
# Variable Created 3 to 80
# Variable Created 3 to 81
# Variable Created 3 to 82
# Variable Created 3 to 83
# Variable Created 3 to 84
# Variable Created 3 to 85
# Variable Created 3 to 86
# Variable Created 3 to 87
# Variable Created 3 to 88
# Variable Created 3 to 89
# Variable Created 3 to 90
# Variable Created 3 to 91
# Variable Created 3 to 92
# Variable Created 3 to 93
# Variable Created 3 to 94
# Variable Created 3 to 95
# Variable Created 3 to 96
# Variable Created 3 to 97
# Variable Created 3 to 98
# Variable Created 3 to 99
# Variable Created 3 to 100
# Variable Created 3 to 101
# Variable Created 3 to 102
# Variable Created 4 to 1
# Variable Created 4 to 2
# Variable Created 4 to 3
# Variable Created 4 to 4
# Variable Created 4 to 5
# Variable Created 4 to 6
# Variable Created 4 to 7
# Variable Created 4 to 8
# Variable Created 4 to 9
# Variable Created 4 to 10
# Variable Created 4 to 11
# Variable Created 4 to 12
# Variable Created 4 to 13
# Variable Created 4 to 14
# Variable Created 4 to 15
# Variable Created 4 to 16
# Variable Created 4 to 17
# Variable Created 4 to 18
# Variable Created 4 to 19
# Variable Created 4 to 20
# Variable Created 4 to 21
# Variable Created 4 to 22
# Variable Created 4 to 23
# Variable Created 4 to 24
# Variable Created 4 to 25
# Variable Created 4 to 26
# Variable Created 4 to 27
# Variable Created 4 to 28
# Variable Created 4 to 29
# Variable Created 4 to 30
# Variable Created 4 to 31
# Variable Created 4 to 32
# Variable Created 4 to 33
# Variable Created 4 to 34
# Variable Created 4 to 35
# Variable Created 4 to 36
# Variable Created 4 to 37
# Variable Created 4 to 38
# Variable Created 4 to 39
# Variable Created 4 to 40
# Variable Created 4 to 41
# Variable Created 4 to 42
# Variable Created 4 to 43
# Variable Created 4 to 44
# Variable Created 4 to 45
# Variable Created 4 to 46
# Variable Created 4 to 47
# Variable Created 4 to 48
# Variable Created 4 to 49
# Variable Created 4 to 50
# Variable Created 4 to 51
# Variable Created 4 to 52
# Variable Created 4 to 53
# Variable Created 4 to 54
# Variable Created 4 to 55
# Variable Created 4 to 56
# Variable Created 4 to 57
# Variable Created 4 to 58
# Variable Created 4 to 59
# Variable Created 4 to 60
# Variable Created 4 to 61
# Variable Created 4 to 62
# Variable Created 4 to 63
# Variable Created 4 to 64
# Variable Created 4 to 65
# Variable Created 4 to 66
# Variable Created 4 to 67
# Variable Created 4 to 68
# Variable Created 4 to 69
# Variable Created 4 to 70
# Variable Created 4 to 71
# Variable Created 4 to 72
# Variable Created 4 to 73
# Variable Created 4 to 74
# Variable Created 4 to 75
# Variable Created 4 to 76
# Variable Created 4 to 77
# Variable Created 4 to 78
# Variable Created 4 to 79
# Variable Created 4 to 80
# Variable Created 4 to 81
# Variable Created 4 to 82
# Variable Created 4 to 83
# Variable Created 4 to 84
# Variable Created 4 to 85
# Variable Created 4 to 86
# Variable Created 4 to 87
# Variable Created 4 to 88
# Variable Created 4 to 89
# Variable Created 4 to 90
# Variable Created 4 to 91
# Variable Created 4 to 92
# Variable Created 4 to 93
# Variable Created 4 to 94
# Variable Created 4 to 95
# Variable Created 4 to 96
# Variable Created 4 to 97
# Variable Created 4 to 98
# Variable Created 4 to 99
# Variable Created 4 to 100
# Variable Created 4 to 101
# Variable Created 4 to 102
# Variable Created 5 to 1
# Variable Created 5 to 2
# Variable Created 5 to 3
# Variable Created 5 to 4
# Variable Created 5 to 5
# Variable Created 5 to 6
# Variable Created 5 to 7
# Variable Created 5 to 8
# Variable Created 5 to 9
# Variable Created 5 to 10
# Variable Created 5 to 11
# Variable Created 5 to 12
# Variable Created 5 to 13
# Variable Created 5 to 14
# Variable Created 5 to 15
# Variable Created 5 to 16
# Variable Created 5 to 17
# Variable Created 5 to 18
# Variable Created 5 to 19
# Variable Created 5 to 20
# Variable Created 5 to 21
# Variable Created 5 to 22
# Variable Created 5 to 23
# Variable Created 5 to 24
# Variable Created 5 to 25
# Variable Created 5 to 26
# Variable Created 5 to 27
# Variable Created 5 to 28
# Variable Created 5 to 29
# Variable Created 5 to 30
# Variable Created 5 to 31
# Variable Created 5 to 32
# Variable Created 5 to 33
# Variable Created 5 to 34
# Variable Created 5 to 35
# Variable Created 5 to 36
# Variable Created 5 to 37
# Variable Created 5 to 38
# Variable Created 5 to 39
# Variable Created 5 to 40
# Variable Created 5 to 41
# Variable Created 5 to 42
# Variable Created 5 to 43
# Variable Created 5 to 44
# Variable Created 5 to 45
# Variable Created 5 to 46
# Variable Created 5 to 47
# Variable Created 5 to 48
# Variable Created 5 to 49
# Variable Created 5 to 50
# Variable Created 5 to 51
# Variable Created 5 to 52
# Variable Created 5 to 53
# Variable Created 5 to 54
# Variable Created 5 to 55
# Variable Created 5 to 56
# Variable Created 5 to 57
# Variable Created 5 to 58
# Variable Created 5 to 59
# Variable Created 5 to 60
# Variable Created 5 to 61
# Variable Created 5 to 62
# Variable Created 5 to 63
# Variable Created 5 to 64
# Variable Created 5 to 65
# Variable Created 5 to 66
# Variable Created 5 to 67
# Variable Created 5 to 68
# Variable Created 5 to 69
# Variable Created 5 to 70
# Variable Created 5 to 71
# Variable Created 5 to 72
# Variable Created 5 to 73
# Variable Created 5 to 74
# Variable Created 5 to 75
# Variable Created 5 to 76
# Variable Created 5 to 77
# Variable Created 5 to 78
# Variable Created 5 to 79
# Variable Created 5 to 80
# Variable Created 5 to 81
# Variable Created 5 to 82
# Variable Created 5 to 83
# Variable Created 5 to 84
# Variable Created 5 to 85
# Variable Created 5 to 86
# Variable Created 5 to 87
# Variable Created 5 to 88
# Variable Created 5 to 89
# Variable Created 5 to 90
# Variable Created 5 to 91
# Variable Created 5 to 92
# Variable Created 5 to 93
# Variable Created 5 to 94
# Variable Created 5 to 95
# Variable Created 5 to 96
# Variable Created 5 to 97
# Variable Created 5 to 98
# Variable Created 5 to 99
# Variable Created 5 to 100
# Variable Created 5 to 101
# Variable Created 5 to 102
# Variable Created 6 to 1
# Variable Created 6 to 2
# Variable Created 6 to 3
# Variable Created 6 to 4
# Variable Created 6 to 5
# Variable Created 6 to 6
# Variable Created 6 to 7
# Variable Created 6 to 8
# Variable Created 6 to 9
# Variable Created 6 to 10
# Variable Created 6 to 11
# Variable Created 6 to 12
# Variable Created 6 to 13
# Variable Created 6 to 14
# Variable Created 6 to 15
# Variable Created 6 to 16
# Variable Created 6 to 17
# Variable Created 6 to 18
# Variable Created 6 to 19
# Variable Created 6 to 20
# Variable Created 6 to 21
# Variable Created 6 to 22
# Variable Created 6 to 23
# Variable Created 6 to 24
# Variable Created 6 to 25
# Variable Created 6 to 26
# Variable Created 6 to 27
# Variable Created 6 to 28
# Variable Created 6 to 29
# Variable Created 6 to 30
# Variable Created 6 to 31
# Variable Created 6 to 32
# Variable Created 6 to 33
# Variable Created 6 to 34
# Variable Created 6 to 35
# Variable Created 6 to 36
# Variable Created 6 to 37
# Variable Created 6 to 38
# Variable Created 6 to 39
# Variable Created 6 to 40
# Variable Created 6 to 41
# Variable Created 6 to 42
# Variable Created 6 to 43
# Variable Created 6 to 44
# Variable Created 6 to 45
# Variable Created 6 to 46
# Variable Created 6 to 47
# Variable Created 6 to 48
# Variable Created 6 to 49
# Variable Created 6 to 50
# Variable Created 6 to 51
# Variable Created 6 to 52
# Variable Created 6 to 53
# Variable Created 6 to 54
# Variable Created 6 to 55
# Variable Created 6 to 56
# Variable Created 6 to 57
# Variable Created 6 to 58
# Variable Created 6 to 59
# Variable Created 6 to 60
# Variable Created 6 to 61
# Variable Created 6 to 62
# Variable Created 6 to 63
# Variable Created 6 to 64
# Variable Created 6 to 65
# Variable Created 6 to 66
# Variable Created 6 to 67
# Variable Created 6 to 68
# Variable Created 6 to 69
# Variable Created 6 to 70
# Variable Created 6 to 71
# Variable Created 6 to 72
# Variable Created 6 to 73
# Variable Created 6 to 74
# Variable Created 6 to 75
# Variable Created 6 to 76
# Variable Created 6 to 77
# Variable Created 6 to 78
# Variable Created 6 to 79
# Variable Created 6 to 80
# Variable Created 6 to 81
# Variable Created 6 to 82
# Variable Created 6 to 83
# Variable Created 6 to 84
# Variable Created 6 to 85
# Variable Created 6 to 86
# Variable Created 6 to 87
# Variable Created 6 to 88
# Variable Created 6 to 89
# Variable Created 6 to 90
# Variable Created 6 to 91
# Variable Created 6 to 92
# Variable Created 6 to 93
# Variable Created 6 to 94
# Variable Created 6 to 95
# Variable Created 6 to 96
# Variable Created 6 to 97
# Variable Created 6 to 98
# Variable Created 6 to 99
# Variable Created 6 to 100
# Variable Created 6 to 101
# Variable Created 6 to 102
# Variable Created 7 to 1
# Variable Created 7 to 2
# Variable Created 7 to 3
# Variable Created 7 to 4
# Variable Created 7 to 5
# Variable Created 7 to 6
# Variable Created 7 to 7
# Variable Created 7 to 8
# Variable Created 7 to 9
# Variable Created 7 to 10
# Variable Created 7 to 11
# Variable Created 7 to 12
# Variable Created 7 to 13
# Variable Created 7 to 14
# Variable Created 7 to 15
# Variable Created 7 to 16
# Variable Created 7 to 17
# Variable Created 7 to 18
# Variable Created 7 to 19
# Variable Created 7 to 20
# Variable Created 7 to 21
# Variable Created 7 to 22
# Variable Created 7 to 23
# Variable Created 7 to 24
# Variable Created 7 to 25
# Variable Created 7 to 26
# Variable Created 7 to 27
# Variable Created 7 to 28
# Variable Created 7 to 29
# Variable Created 7 to 30
# Variable Created 7 to 31
# Variable Created 7 to 32
# Variable Created 7 to 33
# Variable Created 7 to 34
# Variable Created 7 to 35
# Variable Created 7 to 36
# Variable Created 7 to 37
# Variable Created 7 to 38
# Variable Created 7 to 39
# Variable Created 7 to 40
# Variable Created 7 to 41
# Variable Created 7 to 42
# Variable Created 7 to 43
# Variable Created 7 to 44
# Variable Created 7 to 45
# Variable Created 7 to 46
# Variable Created 7 to 47
# Variable Created 7 to 48
# Variable Created 7 to 49
# Variable Created 7 to 50
# Variable Created 7 to 51
# Variable Created 7 to 52
# Variable Created 7 to 53
# Variable Created 7 to 54
# Variable Created 7 to 55
# Variable Created 7 to 56
# Variable Created 7 to 57
# Variable Created 7 to 58
# Variable Created 7 to 59
# Variable Created 7 to 60
# Variable Created 7 to 61
# Variable Created 7 to 62
# Variable Created 7 to 63
# Variable Created 7 to 64
# Variable Created 7 to 65
# Variable Created 7 to 66
# Variable Created 7 to 67
# Variable Created 7 to 68
# Variable Created 7 to 69
# Variable Created 7 to 70
# Variable Created 7 to 71
# Variable Created 7 to 72
# Variable Created 7 to 73
# Variable Created 7 to 74
# Variable Created 7 to 75
# Variable Created 7 to 76
# Variable Created 7 to 77
# Variable Created 7 to 78
# Variable Created 7 to 79
# Variable Created 7 to 80
# Variable Created 7 to 81
# Variable Created 7 to 82
# Variable Created 7 to 83
# Variable Created 7 to 84
# Variable Created 7 to 85
# Variable Created 7 to 86
# Variable Created 7 to 87
# Variable Created 7 to 88
# Variable Created 7 to 89
# Variable Created 7 to 90
# Variable Created 7 to 91
# Variable Created 7 to 92
# Variable Created 7 to 93
# Variable Created 7 to 94
# Variable Created 7 to 95
# Variable Created 7 to 96
# Variable Created 7 to 97
# Variable Created 7 to 98
# Variable Created 7 to 99
# Variable Created 7 to 100
# Variable Created 7 to 101
# Variable Created 7 to 102
# Variable Created 8 to 1
# Variable Created 8 to 2
# Variable Created 8 to 3
# Variable Created 8 to 4
# Variable Created 8 to 5
# Variable Created 8 to 6
# Variable Created 8 to 7
# Variable Created 8 to 8
# Variable Created 8 to 9
# Variable Created 8 to 10
# Variable Created 8 to 11
# Variable Created 8 to 12
# Variable Created 8 to 13
# Variable Created 8 to 14
# Variable Created 8 to 15
# Variable Created 8 to 16
# Variable Created 8 to 17
# Variable Created 8 to 18
# Variable Created 8 to 19
# Variable Created 8 to 20
# Variable Created 8 to 21
# Variable Created 8 to 22
# Variable Created 8 to 23
# Variable Created 8 to 24
# Variable Created 8 to 25
# Variable Created 8 to 26
# Variable Created 8 to 27
# Variable Created 8 to 28
# Variable Created 8 to 29
# Variable Created 8 to 30
# Variable Created 8 to 31
# Variable Created 8 to 32
# Variable Created 8 to 33
# Variable Created 8 to 34
# Variable Created 8 to 35
# Variable Created 8 to 36
# Variable Created 8 to 37
# Variable Created 8 to 38
# Variable Created 8 to 39
# Variable Created 8 to 40
# Variable Created 8 to 41
# Variable Created 8 to 42
# Variable Created 8 to 43
# Variable Created 8 to 44
# Variable Created 8 to 45
# Variable Created 8 to 46
# Variable Created 8 to 47
# Variable Created 8 to 48
# Variable Created 8 to 49
# Variable Created 8 to 50
# Variable Created 8 to 51
# Variable Created 8 to 52
# Variable Created 8 to 53
# Variable Created 8 to 54
# Variable Created 8 to 55
# Variable Created 8 to 56
# Variable Created 8 to 57
# Variable Created 8 to 58
# Variable Created 8 to 59
# Variable Created 8 to 60
# Variable Created 8 to 61
# Variable Created 8 to 62
# Variable Created 8 to 63
# Variable Created 8 to 64
# Variable Created 8 to 65
# Variable Created 8 to 66
# Variable Created 8 to 67
# Variable Created 8 to 68
# Variable Created 8 to 69
# Variable Created 8 to 70
# Variable Created 8 to 71
# Variable Created 8 to 72
# Variable Created 8 to 73
# Variable Created 8 to 74
# Variable Created 8 to 75
# Variable Created 8 to 76
# Variable Created 8 to 77
# Variable Created 8 to 78
# Variable Created 8 to 79
# Variable Created 8 to 80
# Variable Created 8 to 81
# Variable Created 8 to 82
# Variable Created 8 to 83
# Variable Created 8 to 84
# Variable Created 8 to 85
# Variable Created 8 to 86
# Variable Created 8 to 87
# Variable Created 8 to 88
# Variable Created 8 to 89
# Variable Created 8 to 90
# Variable Created 8 to 91
# Variable Created 8 to 92
# Variable Created 8 to 93
# Variable Created 8 to 94
# Variable Created 8 to 95
# Variable Created 8 to 96
# Variable Created 8 to 97
# Variable Created 8 to 98
# Variable Created 8 to 99
# Variable Created 8 to 100
# Variable Created 8 to 101
# Variable Created 8 to 102
# Variable Created 9 to 1
# Variable Created 9 to 2
# Variable Created 9 to 3
# Variable Created 9 to 4
# Variable Created 9 to 5
# Variable Created 9 to 6
# Variable Created 9 to 7
# Variable Created 9 to 8
# Variable Created 9 to 9
# Variable Created 9 to 10
# Variable Created 9 to 11
# Variable Created 9 to 12
# Variable Created 9 to 13
# Variable Created 9 to 14
# Variable Created 9 to 15
# Variable Created 9 to 16
# Variable Created 9 to 17
# Variable Created 9 to 18
# Variable Created 9 to 19
# Variable Created 9 to 20
# Variable Created 9 to 21
# Variable Created 9 to 22
# Variable Created 9 to 23
# Variable Created 9 to 24
# Variable Created 9 to 25
# Variable Created 9 to 26
# Variable Created 9 to 27
# Variable Created 9 to 28
# Variable Created 9 to 29
# Variable Created 9 to 30
# Variable Created 9 to 31
# Variable Created 9 to 32
# Variable Created 9 to 33
# Variable Created 9 to 34
# Variable Created 9 to 35
# Variable Created 9 to 36
# Variable Created 9 to 37
# Variable Created 9 to 38
# Variable Created 9 to 39
# Variable Created 9 to 40
# Variable Created 9 to 41
# Variable Created 9 to 42
# Variable Created 9 to 43
# Variable Created 9 to 44
# Variable Created 9 to 45
# Variable Created 9 to 46
# Variable Created 9 to 47
# Variable Created 9 to 48
# Variable Created 9 to 49
# Variable Created 9 to 50
# Variable Created 9 to 51
# Variable Created 9 to 52
# Variable Created 9 to 53
# Variable Created 9 to 54
# Variable Created 9 to 55
# Variable Created 9 to 56
# Variable Created 9 to 57
# Variable Created 9 to 58
# Variable Created 9 to 59
# Variable Created 9 to 60
# Variable Created 9 to 61
# Variable Created 9 to 62
# Variable Created 9 to 63
# Variable Created 9 to 64
# Variable Created 9 to 65
# Variable Created 9 to 66
# Variable Created 9 to 67
# Variable Created 9 to 68
# Variable Created 9 to 69
# Variable Created 9 to 70
# Variable Created 9 to 71
# Variable Created 9 to 72
# Variable Created 9 to 73
# Variable Created 9 to 74
# Variable Created 9 to 75
# Variable Created 9 to 76
# Variable Created 9 to 77
# Variable Created 9 to 78
# Variable Created 9 to 79
# Variable Created 9 to 80
# Variable Created 9 to 81
# Variable Created 9 to 82
# Variable Created 9 to 83
# Variable Created 9 to 84
# Variable Created 9 to 85
# Variable Created 9 to 86
# Variable Created 9 to 87
# Variable Created 9 to 88
# Variable Created 9 to 89
# Variable Created 9 to 90
# Variable Created 9 to 91
# Variable Created 9 to 92
# Variable Created 9 to 93
# Variable Created 9 to 94
# Variable Created 9 to 95
# Variable Created 9 to 96
# Variable Created 9 to 97
# Variable Created 9 to 98
# Variable Created 9 to 99
# Variable Created 9 to 100
# Variable Created 9 to 101
# Variable Created 9 to 102
# Variable Created 10 to 1
# Variable Created 10 to 2
# Variable Created 10 to 3
# Variable Created 10 to 4
# Variable Created 10 to 5
# Variable Created 10 to 6
# Variable Created 10 to 7
# Variable Created 10 to 8
# Variable Created 10 to 9
# Variable Created 10 to 10
# Variable Created 10 to 11
# Variable Created 10 to 12
# Variable Created 10 to 13
# Variable Created 10 to 14
# Variable Created 10 to 15
# Variable Created 10 to 16
# Variable Created 10 to 17
# Variable Created 10 to 18
# Variable Created 10 to 19
# Variable Created 10 to 20
# Variable Created 10 to 21
# Variable Created 10 to 22
# Variable Created 10 to 23
# Variable Created 10 to 24
# Variable Created 10 to 25
# Variable Created 10 to 26
# Variable Created 10 to 27
# Variable Created 10 to 28
# Variable Created 10 to 29
# Variable Created 10 to 30
# Variable Created 10 to 31
# Variable Created 10 to 32
# Variable Created 10 to 33
# Variable Created 10 to 34
# Variable Created 10 to 35
# Variable Created 10 to 36
# Variable Created 10 to 37
# Variable Created 10 to 38
# Variable Created 10 to 39
# Variable Created 10 to 40
# Variable Created 10 to 41
# Variable Created 10 to 42
# Variable Created 10 to 43
# Variable Created 10 to 44
# Variable Created 10 to 45
# Variable Created 10 to 46
# Variable Created 10 to 47
# Variable Created 10 to 48
# Variable Created 10 to 49
# Variable Created 10 to 50
# Variable Created 10 to 51
# Variable Created 10 to 52
# Variable Created 10 to 53
# Variable Created 10 to 54
# Variable Created 10 to 55
# Variable Created 10 to 56
# Variable Created 10 to 57
# Variable Created 10 to 58
# Variable Created 10 to 59
# Variable Created 10 to 60
# Variable Created 10 to 61
# Variable Created 10 to 62
# Variable Created 10 to 63
# Variable Created 10 to 64
# Variable Created 10 to 65
# Variable Created 10 to 66
# Variable Created 10 to 67
# Variable Created 10 to 68
# Variable Created 10 to 69
# Variable Created 10 to 70
# Variable Created 10 to 71
# Variable Created 10 to 72
# Variable Created 10 to 73
# Variable Created 10 to 74
# Variable Created 10 to 75
# Variable Created 10 to 76
# Variable Created 10 to 77
# Variable Created 10 to 78
# Variable Created 10 to 79
# Variable Created 10 to 80
# Variable Created 10 to 81
# Variable Created 10 to 82
# Variable Created 10 to 83
# Variable Created 10 to 84
# Variable Created 10 to 85
# Variable Created 10 to 86
# Variable Created 10 to 87
# Variable Created 10 to 88
# Variable Created 10 to 89
# Variable Created 10 to 90
# Variable Created 10 to 91
# Variable Created 10 to 92
# Variable Created 10 to 93
# Variable Created 10 to 94
# Variable Created 10 to 95
# Variable Created 10 to 96
# Variable Created 10 to 97
# Variable Created 10 to 98
# Variable Created 10 to 99
# Variable Created 10 to 100
# Variable Created 10 to 101
# Variable Created 10 to 102
# Variable Created 11 to 1
# Variable Created 11 to 2
# Variable Created 11 to 3
# Variable Created 11 to 4
# Variable Created 11 to 5
# Variable Created 11 to 6
# Variable Created 11 to 7
# Variable Created 11 to 8
# Variable Created 11 to 9
# Variable Created 11 to 10
# Variable Created 11 to 11
# Variable Created 11 to 12
# Variable Created 11 to 13
# Variable Created 11 to 14
# Variable Created 11 to 15
# Variable Created 11 to 16
# Variable Created 11 to 17
# Variable Created 11 to 18
# Variable Created 11 to 19
# Variable Created 11 to 20
# Variable Created 11 to 21
# Variable Created 11 to 22
# Variable Created 11 to 23
# Variable Created 11 to 24
# Variable Created 11 to 25
# Variable Created 11 to 26
# Variable Created 11 to 27
# Variable Created 11 to 28
# Variable Created 11 to 29
# Variable Created 11 to 30
# Variable Created 11 to 31
# Variable Created 11 to 32
# Variable Created 11 to 33
# Variable Created 11 to 34
# Variable Created 11 to 35
# Variable Created 11 to 36
# Variable Created 11 to 37
# Variable Created 11 to 38
# Variable Created 11 to 39
# Variable Created 11 to 40
# Variable Created 11 to 41
# Variable Created 11 to 42
# Variable Created 11 to 43
# Variable Created 11 to 44
# Variable Created 11 to 45
# Variable Created 11 to 46
# Variable Created 11 to 47
# Variable Created 11 to 48
# Variable Created 11 to 49
# Variable Created 11 to 50
# Variable Created 11 to 51
# Variable Created 11 to 52
# Variable Created 11 to 53
# Variable Created 11 to 54
# Variable Created 11 to 55
# Variable Created 11 to 56
# Variable Created 11 to 57
# Variable Created 11 to 58
# Variable Created 11 to 59
# Variable Created 11 to 60
# Variable Created 11 to 61
# Variable Created 11 to 62
# Variable Created 11 to 63
# Variable Created 11 to 64
# Variable Created 11 to 65
# Variable Created 11 to 66
# Variable Created 11 to 67
# Variable Created 11 to 68
# Variable Created 11 to 69
# Variable Created 11 to 70
# Variable Created 11 to 71
# Variable Created 11 to 72
# Variable Created 11 to 73
# Variable Created 11 to 74
# Variable Created 11 to 75
# Variable Created 11 to 76
# Variable Created 11 to 77
# Variable Created 11 to 78
# Variable Created 11 to 79
# Variable Created 11 to 80
# Variable Created 11 to 81
# Variable Created 11 to 82
# Variable Created 11 to 83
# Variable Created 11 to 84
# Variable Created 11 to 85
# Variable Created 11 to 86
# Variable Created 11 to 87
# Variable Created 11 to 88
# Variable Created 11 to 89
# Variable Created 11 to 90
# Variable Created 11 to 91
# Variable Created 11 to 92
# Variable Created 11 to 93
# Variable Created 11 to 94
# Variable Created 11 to 95
# Variable Created 11 to 96
# Variable Created 11 to 97
# Variable Created 11 to 98
# Variable Created 11 to 99
# Variable Created 11 to 100
# Variable Created 11 to 101
# Variable Created 11 to 102
# Variable Created 12 to 1
# Variable Created 12 to 2
# Variable Created 12 to 3
# Variable Created 12 to 4
# Variable Created 12 to 5
# Variable Created 12 to 6
# Variable Created 12 to 7
# Variable Created 12 to 8
# Variable Created 12 to 9
# Variable Created 12 to 10
# Variable Created 12 to 11
# Variable Created 12 to 12
# Variable Created 12 to 13
# Variable Created 12 to 14
# Variable Created 12 to 15
# Variable Created 12 to 16
# Variable Created 12 to 17
# Variable Created 12 to 18
# Variable Created 12 to 19
# Variable Created 12 to 20
# Variable Created 12 to 21
# Variable Created 12 to 22
# Variable Created 12 to 23
# Variable Created 12 to 24
# Variable Created 12 to 25
# Variable Created 12 to 26
# Variable Created 12 to 27
# Variable Created 12 to 28
# Variable Created 12 to 29
# Variable Created 12 to 30
# Variable Created 12 to 31
# Variable Created 12 to 32
# Variable Created 12 to 33
# Variable Created 12 to 34
# Variable Created 12 to 35
# Variable Created 12 to 36
# Variable Created 12 to 37
# Variable Created 12 to 38
# Variable Created 12 to 39
# Variable Created 12 to 40
# Variable Created 12 to 41
# Variable Created 12 to 42
# Variable Created 12 to 43
# Variable Created 12 to 44
# Variable Created 12 to 45
# Variable Created 12 to 46
# Variable Created 12 to 47
# Variable Created 12 to 48
# Variable Created 12 to 49
# Variable Created 12 to 50
# Variable Created 12 to 51
# Variable Created 12 to 52
# Variable Created 12 to 53
# Variable Created 12 to 54
# Variable Created 12 to 55
# Variable Created 12 to 56
# Variable Created 12 to 57
# Variable Created 12 to 58
# Variable Created 12 to 59
# Variable Created 12 to 60
# Variable Created 12 to 61
# Variable Created 12 to 62
# Variable Created 12 to 63
# Variable Created 12 to 64
# Variable Created 12 to 65
# Variable Created 12 to 66
# Variable Created 12 to 67
# Variable Created 12 to 68
# Variable Created 12 to 69
# Variable Created 12 to 70
# Variable Created 12 to 71
# Variable Created 12 to 72
# Variable Created 12 to 73
# Variable Created 12 to 74
# Variable Created 12 to 75
# Variable Created 12 to 76
# Variable Created 12 to 77
# Variable Created 12 to 78
# Variable Created 12 to 79
# Variable Created 12 to 80
# Variable Created 12 to 81
# Variable Created 12 to 82
# Variable Created 12 to 83
# Variable Created 12 to 84
# Variable Created 12 to 85
# Variable Created 12 to 86
# Variable Created 12 to 87
# Variable Created 12 to 88
# Variable Created 12 to 89
# Variable Created 12 to 90
# Variable Created 12 to 91
# Variable Created 12 to 92
# Variable Created 12 to 93
# Variable Created 12 to 94
# Variable Created 12 to 95
# Variable Created 12 to 96
# Variable Created 12 to 97
# Variable Created 12 to 98
# Variable Created 12 to 99
# Variable Created 12 to 100
# Variable Created 12 to 101
# Variable Created 12 to 102
# Variable Created 13 to 1
# Variable Created 13 to 2
# Variable Created 13 to 3
# Variable Created 13 to 4
# Variable Created 13 to 5
# Variable Created 13 to 6
# Variable Created 13 to 7
# Variable Created 13 to 8
# Variable Created 13 to 9
# Variable Created 13 to 10
# Variable Created 13 to 11
# Variable Created 13 to 12
# Variable Created 13 to 13
# Variable Created 13 to 14
# Variable Created 13 to 15
# Variable Created 13 to 16
# Variable Created 13 to 17
# Variable Created 13 to 18
# Variable Created 13 to 19
# Variable Created 13 to 20
# Variable Created 13 to 21
# Variable Created 13 to 22
# Variable Created 13 to 23
# Variable Created 13 to 24
# Variable Created 13 to 25
# Variable Created 13 to 26
# Variable Created 13 to 27
# Variable Created 13 to 28
# Variable Created 13 to 29
# Variable Created 13 to 30
# Variable Created 13 to 31
# Variable Created 13 to 32
# Variable Created 13 to 33
# Variable Created 13 to 34
# Variable Created 13 to 35
# Variable Created 13 to 36
# Variable Created 13 to 37
# Variable Created 13 to 38
# Variable Created 13 to 39
# Variable Created 13 to 40
# Variable Created 13 to 41
# Variable Created 13 to 42
# Variable Created 13 to 43
# Variable Created 13 to 44
# Variable Created 13 to 45
# Variable Created 13 to 46
# Variable Created 13 to 47
# Variable Created 13 to 48
# Variable Created 13 to 49
# Variable Created 13 to 50
# Variable Created 13 to 51
# Variable Created 13 to 52
# Variable Created 13 to 53
# Variable Created 13 to 54
# Variable Created 13 to 55
# Variable Created 13 to 56
# Variable Created 13 to 57
# Variable Created 13 to 58
# Variable Created 13 to 59
# Variable Created 13 to 60
# Variable Created 13 to 61
# Variable Created 13 to 62
# Variable Created 13 to 63
# Variable Created 13 to 64
# Variable Created 13 to 65
# Variable Created 13 to 66
# Variable Created 13 to 67
# Variable Created 13 to 68
# Variable Created 13 to 69
# Variable Created 13 to 70
# Variable Created 13 to 71
# Variable Created 13 to 72
# Variable Created 13 to 73
# Variable Created 13 to 74
# Variable Created 13 to 75
# Variable Created 13 to 76
# Variable Created 13 to 77
# Variable Created 13 to 78
# Variable Created 13 to 79
# Variable Created 13 to 80
# Variable Created 13 to 81
# Variable Created 13 to 82
# Variable Created 13 to 83
# Variable Created 13 to 84
# Variable Created 13 to 85
# Variable Created 13 to 86
# Variable Created 13 to 87
# Variable Created 13 to 88
# Variable Created 13 to 89
# Variable Created 13 to 90
# Variable Created 13 to 91
# Variable Created 13 to 92
# Variable Created 13 to 93
# Variable Created 13 to 94
# Variable Created 13 to 95
# Variable Created 13 to 96
# Variable Created 13 to 97
# Variable Created 13 to 98
# Variable Created 13 to 99
# Variable Created 13 to 100
# Variable Created 13 to 101
# Variable Created 13 to 102
# Variable Created 14 to 1
# Variable Created 14 to 2
# Variable Created 14 to 3
# Variable Created 14 to 4
# Variable Created 14 to 5
# Variable Created 14 to 6
# Variable Created 14 to 7
# Variable Created 14 to 8
# Variable Created 14 to 9
# Variable Created 14 to 10
# Variable Created 14 to 11
# Variable Created 14 to 12
# Variable Created 14 to 13
# Variable Created 14 to 14
# Variable Created 14 to 15
# Variable Created 14 to 16
# Variable Created 14 to 17
# Variable Created 14 to 18
# Variable Created 14 to 19
# Variable Created 14 to 20
# Variable Created 14 to 21
# Variable Created 14 to 22
# Variable Created 14 to 23
# Variable Created 14 to 24
# Variable Created 14 to 25
# Variable Created 14 to 26
# Variable Created 14 to 27
# Variable Created 14 to 28
# Variable Created 14 to 29
# Variable Created 14 to 30
# Variable Created 14 to 31
# Variable Created 14 to 32
# Variable Created 14 to 33
# Variable Created 14 to 34
# Variable Created 14 to 35
# Variable Created 14 to 36
# Variable Created 14 to 37
# Variable Created 14 to 38
# Variable Created 14 to 39
# Variable Created 14 to 40
# Variable Created 14 to 41
# Variable Created 14 to 42
# Variable Created 14 to 43
# Variable Created 14 to 44
# Variable Created 14 to 45
# Variable Created 14 to 46
# Variable Created 14 to 47
# Variable Created 14 to 48
# Variable Created 14 to 49
# Variable Created 14 to 50
# Variable Created 14 to 51
# Variable Created 14 to 52
# Variable Created 14 to 53
# Variable Created 14 to 54
# Variable Created 14 to 55
# Variable Created 14 to 56
# Variable Created 14 to 57
# Variable Created 14 to 58
# Variable Created 14 to 59
# Variable Created 14 to 60
# Variable Created 14 to 61
# Variable Created 14 to 62
# Variable Created 14 to 63
# Variable Created 14 to 64
# Variable Created 14 to 65
# Variable Created 14 to 66
# Variable Created 14 to 67
# Variable Created 14 to 68
# Variable Created 14 to 69
# Variable Created 14 to 70
# Variable Created 14 to 71
# Variable Created 14 to 72
# Variable Created 14 to 73
# Variable Created 14 to 74
# Variable Created 14 to 75
# Variable Created 14 to 76
# Variable Created 14 to 77
# Variable Created 14 to 78
# Variable Created 14 to 79
# Variable Created 14 to 80
# Variable Created 14 to 81
# Variable Created 14 to 82
# Variable Created 14 to 83
# Variable Created 14 to 84
# Variable Created 14 to 85
# Variable Created 14 to 86
# Variable Created 14 to 87
# Variable Created 14 to 88
# Variable Created 14 to 89
# Variable Created 14 to 90
# Variable Created 14 to 91
# Variable Created 14 to 92
# Variable Created 14 to 93
# Variable Created 14 to 94
# Variable Created 14 to 95
# Variable Created 14 to 96
# Variable Created 14 to 97
# Variable Created 14 to 98
# Variable Created 14 to 99
# Variable Created 14 to 100
# Variable Created 14 to 101
# Variable Created 14 to 102
# Variable Created 15 to 1
# Variable Created 15 to 2
# Variable Created 15 to 3
# Variable Created 15 to 4
# Variable Created 15 to 5
# Variable Created 15 to 6
# Variable Created 15 to 7
# Variable Created 15 to 8
# Variable Created 15 to 9
# Variable Created 15 to 10
# Variable Created 15 to 11
# Variable Created 15 to 12
# Variable Created 15 to 13
# Variable Created 15 to 14
# Variable Created 15 to 15
# Variable Created 15 to 16
# Variable Created 15 to 17
# Variable Created 15 to 18
# Variable Created 15 to 19
# Variable Created 15 to 20
# Variable Created 15 to 21
# Variable Created 15 to 22
# Variable Created 15 to 23
# Variable Created 15 to 24
# Variable Created 15 to 25
# Variable Created 15 to 26
# Variable Created 15 to 27
# Variable Created 15 to 28
# Variable Created 15 to 29
# Variable Created 15 to 30
# Variable Created 15 to 31
# Variable Created 15 to 32
# Variable Created 15 to 33
# Variable Created 15 to 34
# Variable Created 15 to 35
# Variable Created 15 to 36
# Variable Created 15 to 37
# Variable Created 15 to 38
# Variable Created 15 to 39
# Variable Created 15 to 40
# Variable Created 15 to 41
# Variable Created 15 to 42
# Variable Created 15 to 43
# Variable Created 15 to 44
# Variable Created 15 to 45
# Variable Created 15 to 46
# Variable Created 15 to 47
# Variable Created 15 to 48
# Variable Created 15 to 49
# Variable Created 15 to 50
# Variable Created 15 to 51
# Variable Created 15 to 52
# Variable Created 15 to 53
# Variable Created 15 to 54
# Variable Created 15 to 55
# Variable Created 15 to 56
# Variable Created 15 to 57
# Variable Created 15 to 58
# Variable Created 15 to 59
# Variable Created 15 to 60
# Variable Created 15 to 61
# Variable Created 15 to 62
# Variable Created 15 to 63
# Variable Created 15 to 64
# Variable Created 15 to 65
# Variable Created 15 to 66
# Variable Created 15 to 67
# Variable Created 15 to 68
# Variable Created 15 to 69
# Variable Created 15 to 70
# Variable Created 15 to 71
# Variable Created 15 to 72
# Variable Created 15 to 73
# Variable Created 15 to 74
# ...
# Variable Created 18 to 62
# Variable Created 18 to 63
# Variable Created 18 to 64
# Variable Created 18 to 65
# Variable Created 18 to 66
# Variable Created 18 to 67
# Variable Created 18 to 68
# Variable Created 18 to 69
# Variable Created 18 to 70
# Variable Created 18 to 71
# Variable Created 18 to 72
# Variable Created 18 to 73
# Variable Created 18 to 74
# Variable Created 18 to 75
# Variable Created 18 to 76
# Variable Created 18 to 77
# Variable Created 18 to 78
# Variable Created 18 to 79
# Variable Created 18 to 80
# Variable Created 18 to 81
# Variable Created 18 to 82
# Variable Created 18 to 83
# Variable Created 18 to 84
# Variable Created 18 to 85
# Variable Created 18 to 86
# Variable Created 18 to 87
# Variable Created 18 to 88
# Variable Created 18 to 89
# Variable Created 18 to 90
# Variable Created 18 to 91
# Variable Created 18 to 92
# Variable Created 18 to 93
# Variable Created 18 to 94
# Variable Created 18 to 95
# Variable Created 18 to 96
# Variable Created 18 to 97
# Variable Created 18 to 98
# Variable Created 18 to 99
# Variable Created 18 to 100
# Variable Created 18 to 101
# Variable Created 18 to 102
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 387 rows, 6318 columns and 17118 nonzeros
# Model fingerprint: 0x14917975
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve time: 0.01s
# Presolved: 387 rows, 6318 columns, 17118 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1171568e+04   2.902000e+04   0.000000e+00      0s
#      370    2.2970900e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 370 iterations and 0.04 seconds (0.02 work units)
# Optimal objective  2.297089973e+06
#
# Optimal solution found (same-region only). Minimum Cost = 2,297,089.97
#
# \nFarm->Plant Flows:\n     Farm  Plant  Flow (tons) Plant Region
# 0      4      9        367.0        North
# 1      5      6        499.0        North
# 2      6     16        417.0         West
# 3     14      6        526.0        North
# 4     15      9        441.0        North
# ..   ...    ...          ...          ...
# 69   226      2        386.0        North
# 70   238      6        269.0        North
# 71   240     10        317.0        South
# 72   243      1        413.0        South
# 73   244      2        255.0        North
#
# [74 rows x 4 columns]
# \nPlant->Center Flows:\n      Plant  Center  Flow (tons) Center Region
# 0        1       7        480.0         South
# 1        1       8        149.0          West
# 2        1      10        469.0         North
# 3        1      15        320.0         South
# 4        1      18        437.0          West
# ..     ...     ...          ...           ...
# 98      16      82         92.0         South
# 99      16      93        464.0         South
# 100     16      95         87.0         North
# 101     16      97        250.0         South
# 102     16     102        358.0          East
#
# [103 rows x 4 columns]
# Objective of Same Region Model:
#  133.78969834448876 x_1_1 + 133.93749812154073 x_1_2 + 135.69467087802533 x_1_3 + 136.76787821004586 x_1_4 + 136.35132533030549 x_1_5 + 134.98549498561474 x_1_6 + 136.32063631346475 x_1_7 + 137.47798539719855 x_1_8 + 132.76333201373856 x_1_9 + 134.65079751410138 x_1_10 + 136.4701860921011 x_1_11 + 137.255323604862 x_1_12 + 135.50148023571614 x_1_13 + 137.25179196198457 x_1_14 + 137.011883203874 x_1_15 + 135.31903754628047 x_1_16 + 136.80501224698398 x_1_17 + 135.18418330837275 x_1_18 + 144.26989
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 213 rows, 3186 columns and 7722 nonzeros
# Model fingerprint: 0xd07eca99
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 3e+04]
# Presolve time: 0.02s
# Presolved: 213 rows, 3186 columns, 7722 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1171568e+04   2.902000e+04   0.000000e+00      0s
#      405    5.7129767e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 405 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  5.712976673e+06
#
# Optimal solution found (Quality >= 3 only). Minimum Cost = 5,712,976.67
#
# \nFarm->Plant Flows:\n     Farm  Plant  Flow (tons)
# 0      3     10        516.0
# 1     11     16        256.0
# 2     12      9        261.0
# 3     16      9        289.0
# 4     18     10        525.0
# ..   ...    ...          ...
# 74   235     10        340.0
# 75   237      6        338.0
# 76   241      1        397.0
# 77   246     16        492.0
# 78   247      6        374.0
#
# [79 rows x 3 columns]
# \nPlant->Center Flows:\n      Plant  Center  Flow (tons)
# 0        1       7        480.0
# 1        1       8        149.0
# 2        1      15        320.0
# 3        1      18        437.0
# 4        1      20        258.0
# ..     ...     ...          ...
# 98      16      72        233.0
# 99      16      82         92.0
# 100     16      95         87.0
# 101     16      97        250.0
# 102     16     102        358.0
#
# [103 rows x 3 columns]
#
# 3% plant constraint Model:
#
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 5136 rows, 10800 columns and 35046 nonzeros
# Model fingerprint: 0xcaa00295
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Presolve removed 267 rows and 249 columns
# Presolve time: 0.02s
# Presolved: 4869 rows, 10551 columns, 30066 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 2.850e+04
#  Factor NZ  : 4.294e+04 (roughly 7 MB of memory)
#  Factor Ops : 8.983e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.11 seconds (0.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
#
# Solved in 871 iterations and 0.13 seconds (0.05 work units)
# Infeasible model
# Model ended with status 3
#
# 50% Center Limit Model:
#
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-1235U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2223 rows, 6318 columns and 18954 nonzeros
# Model fingerprint: 0xaa1f363e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 3e+04]
# Presolve removed 1836 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 387 rows, 6318 columns, 17118 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1171568e+04   5.441250e+03   0.000000e+00      0s
#      347    2.3019498e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 347 iterations and 0.04 seconds (0.02 work units)
# Optimal objective  2.301949785e+06
#
# Optimal solution found (50% center limit). Minimum Cost = 2,301,949.78
#
# \nFarm->Plant Flows:\n     Farm  Plant  Flow (tons)
# 0      4      9        367.0
# 1      5      6        499.0
# 2      6     16        417.0
# 3     14      6        526.0
# 4     15      9        441.0
# ..   ...    ...          ...
# 70   226      2        386.0
# 71   238      6        269.0
# 72   240     10        317.0
# 73   243      1        413.0
# 74   244      2        255.0
#
# [75 rows x 3 columns]
# \nPlant->Center Flows:\n      Plant  Center  Flow (tons)
# 0        1       2        174.0
# 1        1       5        170.0
# 2        1       6         43.0
# 3        1       7        240.0
# 4        1       8         74.5
# ..     ...     ...          ...
# 200     16      90         84.0
# 201     16      93        232.0
# 202     16      95         43.5
# 203     16      97        125.0
# 204     16     102        179.0
#
# [205 rows x 3 columns]
